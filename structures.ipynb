# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate


mol=molecule('CO')



slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
add_adsorbate(slab, mol, 2.6, 'fcc')

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_CO_fcc',vasp5=True)  #names need to be changed accordingly

# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate


mol=molecule('CO')



slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
add_adsorbate(slab, mol, 2.6, 'ontop')

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_CO_top',vasp5=True)  #names need to be changed accordingly

# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate


mol=molecule('CO')



slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
add_adsorbate(slab, mol, 2.6, 'bridge')

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_CO_bridge',vasp5=True)  #names need to be changed accordingly

# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate


mol=molecule('CO')



slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
add_adsorbate(slab, mol, 6, 'ontop')

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_CO_away',vasp5=True)  #names need to be changed accordingly

# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate


mol=molecule('CO2')
mol.rotate(90, 'x')
mol.rotate(90, 'z')

slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
add_adsorbate(slab, mol, 6, 'bridge')

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_CO2_away',vasp5=True)  #names need to be changed accordingly

# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate


mol=molecule('HCOOH')

slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
add_adsorbate(slab, mol, 6, 'bridge')

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_HCOOH_away',vasp5=True)  #names need to be changed accordingly

# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate
from ase import Atoms

mol=Atoms('COOH', [ (8.62930,  5.27737  , 21.28688),
(8.62935,   6.60890,  21.66699),
( 8.62928,   4.39472,  22.12007),
(8.62935,   6.62371,  22.65792)])

mol.translate([0,0,-3.5])

slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
# add_adsorbate(slab, mol, 2.6, 'ontop')
slab+=mol

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_COOH_fcc',vasp5=True)  #names need to be changed accordingly

# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate
from ase import Atoms

mol=Atoms('COOH', [ (8.62930,  5.27737  , 21.28688),
(8.62935,   6.60890,  21.66699),
( 8.62928,   4.39472,  22.12007),
(8.62935,   6.62371,  22.65792)])

mol.translate([0,1.8,-3.5])

slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
# add_adsorbate(slab, mol, 2.6, 'ontop')
slab+=mol

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_COOH_top',vasp5=True)  #names need to be changed accordingly

# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate
from ase import Atoms

mol=Atoms('COOH', [ (8.62930,  5.27737 , 21.28688),
(8.62935,   6.60890,  21.66699),
( 8.62928,   4.39472,  22.12007),
(8.62935,   6.62371,  22.65792)])

# mol.rotate(10, 'z')

mol.translate([0.2,-1,-3.5])

slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
# add_adsorbate(slab, mol, 2.6, 'ontop')
slab+=mol

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_COOH_bridge',vasp5=True)  #names need to be changed accordingly

# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate


mol=Atoms('CHO', [ (8.62930,   5.23543,  21.36294),
(8.62934,   6.28551,  21.75299),
( 8.62922,   4.29987,  22.12368)])

# mol.translate([0.2,-1,-3.5])

slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
add_adsorbate(slab, mol, 2, 'ontop')

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_CHO_top',vasp5=True)  #names need to be changed accordingly

# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate


mol=Atoms('CHO', [ (8.62930,   5.23543,  21.36294),
(8.62934,   6.28551,  21.75299),
( 8.62922,   4.29987,  22.12368)])

# mol.translate([0.2,-1,-3.5])

slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
add_adsorbate(slab, mol, 1.7, 'fcc')

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_CHO_fcc',vasp5=True)  #names need to be changed accordingly

# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate


mol=Atoms('CHO', [ (8.62930,   5.23543,  21.36294),
(8.62934,   6.28551,  21.75299),
( 8.62922,   4.29987,  22.12368)])

# mol.translate([0.2,-1,-3.5])

slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
add_adsorbate(slab, mol, 1.7, 'bridge')

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_CHO_bridge',vasp5=True)  #names need to be changed accordingly

# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate


mol=Atoms('CH2O', [ (8.67233 ,  5.00697 , 21.34197),
(9.59071 ,  4.49448,  21.66804),
( 8.68769,   6.05856 , 21.66804),
( 7.48811,   4.32326 , 21.76297)])

# mol.translate([0.2,-1,-3.5])

slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
add_adsorbate(slab, mol, 6, 'ontop')

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_CH2O_away',vasp5=True)  #names need to be changed accordingly

# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate


mol=Atoms('CHOH', [ (8.62931,   5.57954,  21.07429),
(8.62934,   6.63134,  21.42512),
( 8.62928,   4.71472,  22.08831),
( 8.62930 ,  5.16195,  22.96312)])

# mol.translate([0.2,-1,-3.5])

slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
add_adsorbate(slab, mol, 2., 'ontop')

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_CHOH_top',vasp5=True)  #names need to be changed accordingly

# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate


mol=Atoms('CHOH', [ (8.62931,   5.57954,  21.07429),
(8.62934,   6.63134,  21.42512),
( 8.62928,   4.71472,  22.08831),
( 8.62930 ,  5.16195,  22.96312)])

# mol.translate([0.2,-1,-3.5])

slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
add_adsorbate(slab, mol, 1.6, 'fcc')

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_CHOH_fcc',vasp5=True)  #names need to be changed accordingly

# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate


mol=Atoms('CH2OH', [ (8.62931,   5.57954,  21.07429),
(9.42934,   6.43134,  21.42512),
(8.12934,   6.43134,  21.42512),
( 8.62928,   4.71472,  22.08831),
( 8.62930 ,  5.16195,  22.96312)])

# mol.translate([0.2,-1,-3.5])

slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
add_adsorbate(slab, mol, 1.6, 'bridge')

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_CH2OH_bridge',vasp5=True)  #names need to be changed accordingly

# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate


mol=Atoms('CH2OH', [ (8.62931,   5.57954,  21.07429),
(9.42934,   6.43134,  21.42512),
(8.12934,   6.43134,  21.42512),
( 8.62928,   4.71472,  22.08831),
( 8.62930 ,  5.16195,  22.96312)])

# mol.translate([0.2,-1,-3.5])

slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
add_adsorbate(slab, mol, 1.6, 'ontop')

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_CH2OH_top',vasp5=True)  #names need to be changed accordingly

# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate


mol=Atoms('CH2OH', [ (8.62931,   5.57954,  21.07429),
(9.42934,   6.43134,  21.42512),
(8.12934,   6.43134,  21.42512),
( 8.62928,   4.71472,  22.08831),
( 8.62930 ,  5.16195,  22.96312)])

# mol.translate([0.2,-1,-3.5])

slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
add_adsorbate(slab, mol, 1.6, 'fcc')

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_CH2OH_fcc',vasp5=True)  #names need to be changed accordingly

# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate

mol=molecule('CH3OH')
# mol=Atoms('CH2OH', [ (8.62931,   5.57954,  21.07429),
# (9.42934,   6.43134,  21.42512),
# (8.12934,   6.43134,  21.42512),
# ( 8.62928,   4.71472,  22.08831),
# ( 8.62930 ,  5.16195,  22.96312)])

# mol.translate([0.2,-1,-3.5])

slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
add_adsorbate(slab, mol, 6, 'ontop')

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_CH3OH_away',vasp5=True)  #names need to be changed accordingly

# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate


mol=Atoms('CHO', [ (8.62930,   5.23543,  21.36294),
(8.62930,   5.23543,  23.36294),
( 8.62930,   5.23543,  22.36294)])

# mol.translate([0.2,-1,-3.5])

slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
add_adsorbate(slab, mol, 2, 'ontop')

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_COH_top',vasp5=True)  #names need to be changed accordingly

# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate


mol=Atoms('CHO', [ (8.62930,   5.23543,  21.36294),
(8.62930,   5.23543,  23.36294),
( 8.62930,   5.23543,  22.36294)])

# mol.translate([0.2,-1,-3.5])

slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
add_adsorbate(slab, mol, 1.7, 'fcc')

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_COH_fcc',vasp5=True)  #names need to be changed accordingly

# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate


mol=Atoms('CHO', [ (8.62930,   5.23543,  21.36294),
(8.62930,   5.23543,  23.36294),
( 8.62930,   5.23543,  22.36294)])

# mol.translate([0.2,-1,-3.5])

slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
add_adsorbate(slab, mol, 1.8, 'bridge')

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_COH_bridge',vasp5=True)  #names need to be changed accordingly

# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate


mol=molecule('C')



slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
add_adsorbate(slab, mol, 2, 'ontop')

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_C_top',vasp5=True)  #names need to be changed accordingly

# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate


mol=molecule('C')



slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
add_adsorbate(slab, mol, 1.7, 'fcc')

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_C_fcc',vasp5=True)  #names need to be changed accordingly

# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate


mol=molecule('C')



slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
add_adsorbate(slab, mol, 1.7, 'bridge')

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_C_bridge',vasp5=True)  #names need to be changed accordingly

# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate


mol=molecule('CH')
mol.rotate(180, (1,1,0))


slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
add_adsorbate(slab, mol, 2, 'ontop')

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_CH_top',vasp5=True)  #names need to be changed accordingly

# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate


mol=molecule('CH')
mol.rotate(180, (1,1,0))


slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
add_adsorbate(slab, mol, 1.7, 'fcc')

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_CH_fcc',vasp5=True)  #names need to be changed accordingly

# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate


mol=molecule('CH')
mol.rotate(180, (1,1,0))


slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
add_adsorbate(slab, mol, 1.7, 'bridge')

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_CH_bridge',vasp5=True)  #names need to be changed accordingly

# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate


mol=molecule('CH3')
# mol.rotate(180, (1,1,0))


slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
add_adsorbate(slab, mol, 2, 'ontop')

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_CH3_top',vasp5=True)  #names need to be changed accordingly

# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate


mol=molecule('CH3')
# mol.rotate(180, (1,1,0))


slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
add_adsorbate(slab, mol, 1.7, 'fcc')

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_CH3_fcc',vasp5=True)  #names need to be changed accordingly

# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate


mol=molecule('CH3')
# mol.rotate(180, (1,1,0))


slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
add_adsorbate(slab, mol, 1.7, 'bridge')

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_CH3_bridge',vasp5=True)  #names need to be changed accordingly

# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate


mol=molecule('CH4')
# mol.rotate(180, (1,1,0))


slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
add_adsorbate(slab, mol, 7, 'ontop')

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_CH4_away',vasp5=True)  #names need to be changed accordingly

# %%
from ase.build import fcc111
from ase.io import write,read
from ase.build import surface
from ase.visualize import view
from ase.constraints import FixAtoms
from ase.build import add_adsorbate
from ase.build import molecule, rotate


mol=Atoms('O2CH', [ (10.08102,   7.50039,  21.20458),
(11.51464,   4.99597 , 21.20458),
( 10.71176 ,  6.18452 , 21.90780),
 ( 10.71176 ,  6.18452 , 22.96837)       ])

mol.translate([-0.9,-0.9,-3.2])

slab =fcc111('Cu', size =(4, 4, 4), a=3.5677010019476443,  vacuum=10)
# add_adsorbate(slab, mol, 1.8, 'bridge')
slab+=mol

constraint = FixAtoms(mask=slab.positions[:,2] < 13.0)
slab.set_constraint(constraint)
slab.write('POSCAR_Cu111_HCOO',vasp5=True)  #names need to be changed accordingly
